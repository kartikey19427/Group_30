# %%
pip install linkedin-jobs-scraper
# Out:
# Collecting linkedin-jobs-scraper
#   Downloading linkedin_jobs_scraper-2.0.6-py3-none-any.whl (34 kB)
# Collecting selenium<4.0.0,>=3.141.0
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
#      -------------------------------------- 904.6/904.6 kB 3.4 MB/s eta 0:00:00
# Collecting websocket-client<1.0.0,>=0.58.0
#   Downloading websocket_client-0.59.0-py2.py3-none-any.whl (67 kB)
#      -------------------------------------- 67.2/67.2 kB 730.5 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from linkedin-jobs-scraper) (2.27.1)
# Requirement already satisfied: urllib3 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from selenium<4.0.0,>=3.141.0->linkedin-jobs-scraper) (1.26.9)
# Requirement already satisfied: six in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from websocket-client<1.0.0,>=0.58.0->linkedin-jobs-scraper) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from requests->linkedin-jobs-scraper) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from requests->linkedin-jobs-scraper) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from requests->linkedin-jobs-scraper) (3.3)
# Installing collected packages: websocket-client, selenium, linkedin-jobs-scraper
#   Attempting uninstall: selenium
#     Found existing installation: selenium 4.2.0
#     Uninstalling selenium-4.2.0:
#       Successfully uninstalled selenium-4.2.0
# Successfully installed linkedin-jobs-scraper-2.0.6 selenium-3.141.0 websocket-client-0.59.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning) 
warnings.filterwarnings("ignore", category=DeprecationWarning)
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
from linkedin_jobs_scraper import LinkedinScraper
from linkedin_jobs_scraper.events import Events, EventData, EventMetrics
from linkedin_jobs_scraper.query import Query, QueryOptions, QueryFilters
from linkedin_jobs_scraper.filters import RelevanceFilters, TimeFilters, TypeFilters, ExperienceLevelFilters, OnSiteOrRemoteFilters

# %%
logging.basicConfig(level=logging.INFO)

# %%
# Fired once for each successfully processed job
software_developer = []
def on_data(data: EventData):
    software_developer.append([data.job_id, data.title, data.company, data.description, ['Software Developer']])


# Fired once for each page (25 jobs)
def on_metrics(metrics: EventMetrics):
    print('[ON_METRICS]', str(metrics))


def on_error(error):
    print('[ON_ERROR]', error)


def on_end():
    print('[ON_END]')


scraper = LinkedinScraper(
    chrome_executable_path=ChromeDriverManager().install(),  # Custom Chrome executable path (e.g. /foo/bar/bin/chromedriver) 
    chrome_options=None,  # Custom Chrome options here
    headless=True,  # Overrides headless mode only if chrome_options is None
    max_workers=1,  # How many threads will be spawned to run queries concurrently (one Chrome driver for each thread)
    slow_mo=7,  # Slow down the scraper to avoid 'Too many requests 429' errors (in seconds)
    page_load_timeout=70  # Page load timeout (in seconds)    
)

# Add event listeners
scraper.on(Events.DATA, on_data)
scraper.on(Events.ERROR, on_error)
scraper.on(Events.END, on_end)

queries = [
    Query(
        query='Software Developer',
        options=QueryOptions(
            apply_link=False,  # Try to extract apply link (easy applies are skipped). If set to True, scraping is slower because an additional page mus be navigated. Default to False.
            skip_promoted_jobs=False,  # Skip promoted jobs. Default to False.
            limit=100,
        )
    ),
]

scraper.run(queries)
# Out:
# INFO:WDM:====== WebDriver manager ======
# INFO:WDM:Get LATEST chromedriver version for google-chrome 110.0.5481
# INFO:WDM:Driver [C:\Users\pc\.wdm\drivers\chromedriver\win32\110.0.5481\chromedriver.exe] found in cache
# INFO:li:scraper:('Using strategy AnonymousStrategy',)
# WARNING:li:scraper:("AnonymousStrategy is no longer maintained and it won't probably work. It is recommended to use an authenticated session, see documentation at https://github.com/spinlud/py-linkedin-jobs-scraper#anonymous-vs-authenticated-session.",)
# INFO:li:scraper:('Starting new query', "Query(query=Software Developer options=QueryOptions(limit=100 locations=['Worldwide'] optimize=False apply_link=False skip_promoted_jobs=False))")
# INFO:li:scraper:('Chrome debugger url', 'http://localhost:52356')
# INFO:li:scraper:('[Software Developer][Worldwide]', 'Opening https://www.linkedin.com/jobs/search?keywords=Software+Developer&location=Worldwide')
# INFO:li:scraper:('[Software Developer][Worldwide]', 'Trying first selectors set')
# INFO:li:scraper:('[Software Developer][Worldwide]', 'Trying second selectors set')
# INFO:li:scraper:('[Software Developer][Worldwide]', 'OK')
# INFO:li:scraper:('[Software Developer][Worldwide]', 'Starting pagination loop')
# INFO:li:scraper:('[Software Developer][Worldwide]', 'Found 25 jobs')
# INFO:li:scraper:('[Software Developer][Worldwide][1]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][2]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][3]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][4]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][5]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][6]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][7]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][8]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][9]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][10]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][11]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][12]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][13]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][14]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][15]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][16]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][17]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][18]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][19]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][20]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][21]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][22]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][23]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][24]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][25]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][26]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][27]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][28]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][29]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][30]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][31]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][32]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][33]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][34]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][35]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][36]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][37]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][38]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][39]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][40]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][41]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][42]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][43]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][44]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][45]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][46]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][47]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][48]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][49]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][50]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][51]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][52]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][53]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][54]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][55]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][56]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][57]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][58]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][59]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][60]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][61]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][62]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][63]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][64]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][65]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][66]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][67]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][68]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][69]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][70]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][71]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][72]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][73]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][74]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][75]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][76]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][77]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][78]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][79]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][80]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][81]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][82]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][83]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][84]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][85]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][86]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][87]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][88]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][89]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][90]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][91]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][92]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][93]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][94]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][95]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][96]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][97]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][98]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][99]', 'Processed')
# INFO:li:scraper:('[Software Developer][Worldwide][100]', 'Processed')
# [ON_END]

# %%
# Fired once for each successfully processed job
business_analyst = []
def on_data(data: EventData):
    business_analyst.append([data.job_id, data.title, data.company, data.description, ['Business Analyst']])


# Fired once for each page (25 jobs)
def on_metrics(metrics: EventMetrics):
    print('[ON_METRICS]', str(metrics))


def on_error(error):
    print('[ON_ERROR]', error)


def on_end():
    print('[ON_END]')


scraper = LinkedinScraper(
    chrome_executable_path=ChromeDriverManager().install(),  # Custom Chrome executable path (e.g. /foo/bar/bin/chromedriver) 
    chrome_options=None,  # Custom Chrome options here
    headless=True,  # Overrides headless mode only if chrome_options is None
    max_workers=1,  # How many threads will be spawned to run queries concurrently (one Chrome driver for each thread)
    slow_mo=7,  # Slow down the scraper to avoid 'Too many requests 429' errors (in seconds)
    page_load_timeout=70  # Page load timeout (in seconds)    
)

# Add event listeners
scraper.on(Events.DATA, on_data)
scraper.on(Events.ERROR, on_error)
scraper.on(Events.END, on_end)

queries = [
    Query(
        query='Business Analyst',
        options=QueryOptions(
            apply_link=False,  # Try to extract apply link (easy applies are skipped). If set to True, scraping is slower because an additional page mus be navigated. Default to False.
            skip_promoted_jobs=False,  # Skip promoted jobs. Default to False.
            limit=100,
        )
    ),
]

scraper.run(queries)
# Out:
# INFO:WDM:====== WebDriver manager ======
# INFO:WDM:Get LATEST chromedriver version for google-chrome 110.0.5481
# INFO:WDM:Driver [C:\Users\pc\.wdm\drivers\chromedriver\win32\110.0.5481\chromedriver.exe] found in cache
# INFO:li:scraper:('Using strategy AnonymousStrategy',)
# WARNING:li:scraper:("AnonymousStrategy is no longer maintained and it won't probably work. It is recommended to use an authenticated session, see documentation at https://github.com/spinlud/py-linkedin-jobs-scraper#anonymous-vs-authenticated-session.",)
# INFO:li:scraper:('Starting new query', "Query(query=Business Analyst options=QueryOptions(limit=100 locations=['Worldwide'] optimize=False apply_link=False skip_promoted_jobs=False))")
# INFO:li:scraper:('Chrome debugger url', 'http://localhost:52400')
# INFO:li:scraper:('[Business Analyst][Worldwide]', 'Opening https://www.linkedin.com/jobs/search?keywords=Business+Analyst&location=Worldwide')
# INFO:li:scraper:('[Business Analyst][Worldwide]', 'Trying first selectors set')
# INFO:li:scraper:('[Business Analyst][Worldwide]', 'Trying second selectors set')
# INFO:li:scraper:('[Business Analyst][Worldwide]', 'OK')
# INFO:li:scraper:('[Business Analyst][Worldwide]', 'Starting pagination loop')
# INFO:li:scraper:('[Business Analyst][Worldwide]', 'Found 25 jobs')
# INFO:li:scraper:('[Business Analyst][Worldwide][1]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][2]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][3]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][4]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][5]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][6]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][7]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][8]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][9]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][10]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][11]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][12]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][13]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][14]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][15]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][16]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][17]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][18]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][19]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][20]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][21]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][22]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][23]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][24]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][25]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][26]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][27]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][28]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][29]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][30]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][31]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][32]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][33]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][34]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][35]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][36]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][37]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][38]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][39]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][40]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][41]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][42]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][43]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][44]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][45]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][46]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][47]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][48]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][49]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][50]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][51]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][52]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][53]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][54]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][55]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][56]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][57]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][58]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][59]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][60]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][61]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][62]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][63]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][64]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][65]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][66]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][67]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][68]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][69]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][70]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][71]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][72]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][73]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][74]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][75]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][76]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][77]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][78]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][79]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][80]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][81]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][82]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][83]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][84]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][85]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][86]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][87]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][88]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][89]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][90]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][91]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][92]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][93]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][94]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][95]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][96]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][97]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][98]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][99]', 'Processed')
# INFO:li:scraper:('[Business Analyst][Worldwide][100]', 'Processed')
# [ON_END]

# %%
# Fired once for each successfully processed job
marketing_analyst = []
def on_data(data: EventData):
    marketing_analyst.append([data.job_id, data.title, data.company, data.description, ['Marketing Analyst']])


# Fired once for each page (25 jobs)
def on_metrics(metrics: EventMetrics):
    print('[ON_METRICS]', str(metrics))


def on_error(error):
    print('[ON_ERROR]', error)


def on_end():
    print('[ON_END]')


scraper = LinkedinScraper(
    chrome_executable_path=ChromeDriverManager().install(),  # Custom Chrome executable path (e.g. /foo/bar/bin/chromedriver) 
    chrome_options=None,  # Custom Chrome options here
    headless=True,  # Overrides headless mode only if chrome_options is None
    max_workers=1,  # How many threads will be spawned to run queries concurrently (one Chrome driver for each thread)
    slow_mo=7,  # Slow down the scraper to avoid 'Too many requests 429' errors (in seconds)
    page_load_timeout=70  # Page load timeout (in seconds)    
)

# Add event listeners
scraper.on(Events.DATA, on_data)
scraper.on(Events.ERROR, on_error)
scraper.on(Events.END, on_end)

queries = [
    Query(
        query='Marketing Analyst',
        options=QueryOptions(
            apply_link=False,  # Try to extract apply link (easy applies are skipped). If set to True, scraping is slower because an additional page mus be navigated. Default to False.
            skip_promoted_jobs=False,  # Skip promoted jobs. Default to False.
            limit=150,
        )
    ),
]

scraper.run(queries)
# Out:
# INFO:WDM:====== WebDriver manager ======
# INFO:WDM:Get LATEST chromedriver version for google-chrome 110.0.5481
# INFO:WDM:Driver [C:\Users\pc\.wdm\drivers\chromedriver\win32\110.0.5481\chromedriver.exe] found in cache
# INFO:li:scraper:('Using strategy AnonymousStrategy',)
# WARNING:li:scraper:("AnonymousStrategy is no longer maintained and it won't probably work. It is recommended to use an authenticated session, see documentation at https://github.com/spinlud/py-linkedin-jobs-scraper#anonymous-vs-authenticated-session.",)
# INFO:li:scraper:('Starting new query', "Query(query=Marketing Analyst options=QueryOptions(limit=150 locations=['Worldwide'] optimize=False apply_link=False skip_promoted_jobs=False))")
# INFO:li:scraper:('Chrome debugger url', 'http://localhost:52459')
# INFO:li:scraper:('[Marketing Analyst][Worldwide]', 'Opening https://www.linkedin.com/jobs/search?keywords=Marketing+Analyst&location=Worldwide')
# INFO:li:scraper:('[Marketing Analyst][Worldwide]', 'Trying first selectors set')
# INFO:li:scraper:('[Marketing Analyst][Worldwide]', 'Trying second selectors set')
# INFO:li:scraper:('[Marketing Analyst][Worldwide]', 'OK')
# INFO:li:scraper:('[Marketing Analyst][Worldwide]', 'Starting pagination loop')
# INFO:li:scraper:('[Marketing Analyst][Worldwide]', 'Found 25 jobs')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][1]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][2]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][3]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][4]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][5]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][6]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][7]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][8]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][9]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][10]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][11]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][12]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][13]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][14]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][15]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][16]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][17]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][18]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][19]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][20]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][21]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][22]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][23]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][24]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][25]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][26]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][27]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][28]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][29]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][30]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][31]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][32]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][33]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][34]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][35]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][36]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][37]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][38]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][39]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][40]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][41]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][42]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][43]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][44]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][45]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][46]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][47]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][48]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][49]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][50]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][51]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][52]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][53]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][54]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][55]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][56]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][57]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][58]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][59]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][60]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][61]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][62]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][63]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][64]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][65]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][66]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][67]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][68]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][69]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][70]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][71]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][72]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][73]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][74]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][75]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][76]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][77]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][78]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][79]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][80]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][81]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][82]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][83]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][84]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][85]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][86]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][87]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][88]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][89]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][90]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][91]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][92]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][93]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][94]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][95]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][96]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][97]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][98]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][99]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][100]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][101]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][102]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][103]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][104]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][105]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][106]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][107]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][108]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][109]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][110]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][111]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][112]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][113]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][114]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][115]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][116]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][117]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][118]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][119]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][120]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][121]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][122]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][123]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][124]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][125]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][126]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][127]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][128]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][129]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][130]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][131]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][132]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][133]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][134]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][135]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][136]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][137]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][138]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][139]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][140]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][141]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][142]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][143]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][144]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][145]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][146]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][147]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][148]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][149]', 'Processed')
# INFO:li:scraper:('[Marketing Analyst][Worldwide][150]', 'Processed')
# [ON_END]

# %%
# Fired once for each successfully processed job
sales_analyst = []
def on_data(data: EventData):
    sales_analyst.append([data.job_id, data.title, data.company, data.description, ['Sales Analyst']])


# Fired once for each page (25 jobs)
def on_metrics(metrics: EventMetrics):
    print('[ON_METRICS]', str(metrics))


def on_error(error):
    print('[ON_ERROR]', error)


def on_end():
    print('[ON_END]')


scraper = LinkedinScraper(
    chrome_executable_path=ChromeDriverManager().install(),  # Custom Chrome executable path (e.g. /foo/bar/bin/chromedriver) 
    chrome_options=None,  # Custom Chrome options here
    headless=True,  # Overrides headless mode only if chrome_options is None
    max_workers=1,  # How many threads will be spawned to run queries concurrently (one Chrome driver for each thread)
    slow_mo=7,  # Slow down the scraper to avoid 'Too many requests 429' errors (in seconds)
    page_load_timeout=70  # Page load timeout (in seconds)    
)

# Add event listeners
scraper.on(Events.DATA, on_data)
scraper.on(Events.ERROR, on_error)
scraper.on(Events.END, on_end)

queries = [
    Query(
        query='Sales Analyst',
        options=QueryOptions(
            apply_link=False,  # Try to extract apply link (easy applies are skipped). If set to True, scraping is slower because an additional page mus be navigated. Default to False.
            skip_promoted_jobs=False,  # Skip promoted jobs. Default to False.
            limit=110,
        )
    ),
]

scraper.run(queries)
# Out:
# INFO:WDM:====== WebDriver manager ======
# INFO:WDM:Get LATEST chromedriver version for google-chrome 110.0.5481
# INFO:WDM:Driver [C:\Users\pc\.wdm\drivers\chromedriver\win32\110.0.5481\chromedriver.exe] found in cache
# INFO:li:scraper:('Using strategy AnonymousStrategy',)
# WARNING:li:scraper:("AnonymousStrategy is no longer maintained and it won't probably work. It is recommended to use an authenticated session, see documentation at https://github.com/spinlud/py-linkedin-jobs-scraper#anonymous-vs-authenticated-session.",)
# INFO:li:scraper:('Starting new query', "Query(query=Sales Analyst options=QueryOptions(limit=110 locations=['Worldwide'] optimize=False apply_link=False skip_promoted_jobs=False))")
# INFO:li:scraper:('Chrome debugger url', 'http://localhost:52560')
# INFO:li:scraper:('[Sales Analyst][Worldwide]', 'Opening https://www.linkedin.com/jobs/search?keywords=Sales+Analyst&location=Worldwide')
# INFO:li:scraper:('[Sales Analyst][Worldwide]', 'Trying first selectors set')
# INFO:li:scraper:('[Sales Analyst][Worldwide]', 'Trying second selectors set')
# INFO:li:scraper:('[Sales Analyst][Worldwide]', 'OK')
# INFO:li:scraper:('[Sales Analyst][Worldwide]', 'Starting pagination loop')
# INFO:li:scraper:('[Sales Analyst][Worldwide]', 'Found 25 jobs')
# INFO:li:scraper:('[Sales Analyst][Worldwide][1]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][2]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][3]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][4]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][5]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][6]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][7]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][8]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][9]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][10]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][11]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][12]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][13]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][14]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][15]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][16]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][17]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][18]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][19]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][20]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][21]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][22]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][23]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][24]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][25]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][26]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][27]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][28]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][29]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][30]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][31]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][32]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][33]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][34]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][35]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][36]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][37]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][38]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][39]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][40]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][41]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][42]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][43]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][44]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][45]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][46]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][47]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][48]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][49]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][50]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][51]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][52]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][53]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][54]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][55]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][56]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][57]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][58]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][59]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][60]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][61]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][62]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][63]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][64]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][65]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][66]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][67]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][68]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][69]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][70]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][71]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][72]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][73]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][74]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][75]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][76]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][77]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][78]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][79]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][80]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][81]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][82]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][83]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][84]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][85]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][86]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][87]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][88]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][89]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][90]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][91]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][92]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][93]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][94]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][95]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][96]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][97]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][98]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][99]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][100]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][101]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][102]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][103]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][104]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][105]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][106]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][107]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][108]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][109]', 'Processed')
# INFO:li:scraper:('[Sales Analyst][Worldwide][110]', 'Processed')
# [ON_END]

# %%
# Fired once for each successfully processed job
ux_designer = []
def on_data(data: EventData):
    ux_designer.append([data.job_id, data.title, data.company, data.description, ['UX Designer']])


# Fired once for each page (25 jobs)
def on_metrics(metrics: EventMetrics):
    print('[ON_METRICS]', str(metrics))


def on_error(error):
    print('[ON_ERROR]', error)


def on_end():
    print('[ON_END]')


scraper = LinkedinScraper(
    chrome_executable_path=ChromeDriverManager().install(),  # Custom Chrome executable path (e.g. /foo/bar/bin/chromedriver) 
    chrome_options=None,  # Custom Chrome options here
    headless=True,  # Overrides headless mode only if chrome_options is None
    max_workers=1,  # How many threads will be spawned to run queries concurrently (one Chrome driver for each thread)
    slow_mo=7,  # Slow down the scraper to avoid 'Too many requests 429' errors (in seconds)
    page_load_timeout=70  # Page load timeout (in seconds)    
)

# Add event listeners
scraper.on(Events.DATA, on_data)
scraper.on(Events.ERROR, on_error)
scraper.on(Events.END, on_end)

queries = [
    Query(
        query='UX Designer',
        options=QueryOptions(
            apply_link=False,  # Try to extract apply link (easy applies are skipped). If set to True, scraping is slower because an additional page mus be navigated. Default to False.
            skip_promoted_jobs=False,  # Skip promoted jobs. Default to False.
            limit=120,
        )
    ),
]

scraper.run(queries)
# Out:
# INFO:WDM:====== WebDriver manager ======
# INFO:WDM:Get LATEST chromedriver version for google-chrome 110.0.5481
# INFO:WDM:Driver [C:\Users\pc\.wdm\drivers\chromedriver\win32\110.0.5481\chromedriver.exe] found in cache
# INFO:li:scraper:('Using strategy AnonymousStrategy',)
# WARNING:li:scraper:("AnonymousStrategy is no longer maintained and it won't probably work. It is recommended to use an authenticated session, see documentation at https://github.com/spinlud/py-linkedin-jobs-scraper#anonymous-vs-authenticated-session.",)
# INFO:li:scraper:('Starting new query', "Query(query=UX Designer options=QueryOptions(limit=120 locations=['Worldwide'] optimize=False apply_link=False skip_promoted_jobs=False))")
# INFO:li:scraper:('Chrome debugger url', 'http://localhost:52603')
# INFO:li:scraper:('[UX Designer][Worldwide]', 'Opening https://www.linkedin.com/jobs/search?keywords=UX+Designer&location=Worldwide')
# INFO:li:scraper:('[UX Designer][Worldwide]', 'Trying first selectors set')
# INFO:li:scraper:('[UX Designer][Worldwide]', 'Trying second selectors set')
# INFO:li:scraper:('[UX Designer][Worldwide]', 'OK')
# INFO:li:scraper:('[UX Designer][Worldwide]', 'Starting pagination loop')
# INFO:li:scraper:('[UX Designer][Worldwide]', 'Found 25 jobs')
# INFO:li:scraper:('[UX Designer][Worldwide][1]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][2]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][3]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][4]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][5]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][6]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][7]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][8]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][9]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][10]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][11]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][12]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][13]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][14]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][15]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][16]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][17]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][18]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][19]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][20]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][21]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][22]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][23]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][24]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][25]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][26]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][27]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][28]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][29]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][30]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][31]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][32]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][33]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][34]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][35]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][36]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][37]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][38]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][39]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][40]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][41]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][42]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][43]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][44]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][45]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][46]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][47]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][48]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][49]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][50]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][51]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][52]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][53]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][54]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][55]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][56]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][57]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][58]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][59]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][60]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][61]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][62]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][63]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][64]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][65]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][66]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][67]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][68]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][69]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][70]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][71]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][72]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][73]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][74]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][75]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][76]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][77]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][78]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][79]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][80]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][81]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][82]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][83]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][84]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][85]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][86]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][87]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][88]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][89]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][90]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][91]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][92]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][93]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][94]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][95]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][96]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][97]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][98]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][99]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][100]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][101]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][102]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][103]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][104]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][105]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][106]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][107]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][108]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][109]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][110]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][111]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][112]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][113]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][114]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][115]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][116]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][117]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][118]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][119]', 'Processed')
# INFO:li:scraper:('[UX Designer][Worldwide][120]', 'Processed')
# [ON_END]

# %%
# Fired once for each successfully processed job
product_manager = []
def on_data(data: EventData):
    product_manager.append([data.job_id, data.title, data.company, data.description, ['Product Manager']])


# Fired once for each page (25 jobs)
def on_metrics(metrics: EventMetrics):
    print('[ON_METRICS]', str(metrics))


def on_error(error):
    print('[ON_ERROR]', error)


def on_end():
    print('[ON_END]')


scraper = LinkedinScraper(
    chrome_executable_path=ChromeDriverManager().install(),  # Custom Chrome executable path (e.g. /foo/bar/bin/chromedriver) 
    chrome_options=None,  # Custom Chrome options here
    headless=True,  # Overrides headless mode only if chrome_options is None
    max_workers=1,  # How many threads will be spawned to run queries concurrently (one Chrome driver for each thread)
    slow_mo=7,  # Slow down the scraper to avoid 'Too many requests 429' errors (in seconds)
    page_load_timeout=70  # Page load timeout (in seconds)    
)

# Add event listeners
scraper.on(Events.DATA, on_data)
scraper.on(Events.ERROR, on_error)
scraper.on(Events.END, on_end)

queries = [
    Query(
        query='Product Manager',
        options=QueryOptions(
            apply_link=False,  # Try to extract apply link (easy applies are skipped). If set to True, scraping is slower because an additional page mus be navigated. Default to False.
            skip_promoted_jobs=False,  # Skip promoted jobs. Default to False.
            limit=150,
        )
    ),
]

scraper.run(queries)
# Out:
# INFO:WDM:====== WebDriver manager ======
# INFO:WDM:Get LATEST chromedriver version for google-chrome 110.0.5481
# INFO:WDM:Driver [C:\Users\pc\.wdm\drivers\chromedriver\win32\110.0.5481\chromedriver.exe] found in cache
# INFO:li:scraper:('Using strategy AnonymousStrategy',)
# WARNING:li:scraper:("AnonymousStrategy is no longer maintained and it won't probably work. It is recommended to use an authenticated session, see documentation at https://github.com/spinlud/py-linkedin-jobs-scraper#anonymous-vs-authenticated-session.",)
# INFO:li:scraper:('Starting new query', "Query(query=Product Manager options=QueryOptions(limit=150 locations=['Worldwide'] optimize=False apply_link=False skip_promoted_jobs=False))")
# INFO:li:scraper:('Chrome debugger url', 'http://localhost:52639')
# INFO:li:scraper:('[Product Manager][Worldwide]', 'Opening https://www.linkedin.com/jobs/search?keywords=Product+Manager&location=Worldwide')
# INFO:li:scraper:('[Product Manager][Worldwide]', 'Trying first selectors set')
# INFO:li:scraper:('[Product Manager][Worldwide]', 'Trying second selectors set')
# INFO:li:scraper:('[Product Manager][Worldwide]', 'OK')
# INFO:li:scraper:('[Product Manager][Worldwide]', 'Starting pagination loop')
# INFO:li:scraper:('[Product Manager][Worldwide]', 'Found 25 jobs')
# INFO:li:scraper:('[Product Manager][Worldwide][1]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][2]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][3]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][4]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][5]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][6]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][7]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][8]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][9]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][10]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][11]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][12]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][13]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][14]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][15]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][16]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][17]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][18]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][19]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][20]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][21]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][22]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][23]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][24]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][25]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][26]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][27]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][28]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][29]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][30]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][31]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][32]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][33]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][34]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][35]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][36]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][37]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][38]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][39]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][40]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][41]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][42]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][43]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][44]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][45]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][46]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][47]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][48]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][49]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][50]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][51]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][52]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][53]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][54]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][55]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][56]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][57]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][58]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][59]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][60]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][61]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][62]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][63]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][64]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][65]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][66]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][67]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][68]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][69]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][70]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][71]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][72]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][73]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][74]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][75]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][76]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][77]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][78]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][79]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][80]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][81]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][82]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][83]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][84]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][85]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][86]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][87]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][88]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][89]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][90]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][91]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][92]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][93]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][94]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][95]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][96]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][97]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][98]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][99]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][100]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][101]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][102]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][103]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][104]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][105]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][106]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][107]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][108]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][109]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][110]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][111]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][112]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][113]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][114]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][115]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][116]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][117]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][118]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][119]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][120]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][121]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][122]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][123]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][124]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][125]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][126]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][127]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][128]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][129]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][130]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][131]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][132]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][133]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][134]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][135]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][136]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][137]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][138]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][139]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][140]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][141]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][142]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][143]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][144]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][145]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][146]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][147]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][148]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][149]', 'Processed')
# INFO:li:scraper:('[Product Manager][Worldwide][150]', 'Processed')
# [ON_END]

# %%
# Fired once for each successfully processed job
account_manager = []
def on_data(data: EventData):
    account_manager.append([data.job_id, data.title, data.company, data.description, ['Account Manager']])


# Fired once for each page (25 jobs)
def on_metrics(metrics: EventMetrics):
    print('[ON_METRICS]', str(metrics))


def on_error(error):
    print('[ON_ERROR]', error)


def on_end():
    print('[ON_END]')


scraper = LinkedinScraper(
    chrome_executable_path=ChromeDriverManager().install(),  # Custom Chrome executable path (e.g. /foo/bar/bin/chromedriver) 
    chrome_options=None,  # Custom Chrome options here
    headless=True,  # Overrides headless mode only if chrome_options is None
    max_workers=1,  # How many threads will be spawned to run queries concurrently (one Chrome driver for each thread)
    slow_mo=7,  # Slow down the scraper to avoid 'Too many requests 429' errors (in seconds)
    page_load_timeout=70  # Page load timeout (in seconds)    
)

# Add event listeners
scraper.on(Events.DATA, on_data)
scraper.on(Events.ERROR, on_error)
scraper.on(Events.END, on_end)

queries = [
    Query(
        query='Account Manager',
        options=QueryOptions(
            apply_link=False,  # Try to extract apply link (easy applies are skipped). If set to True, scraping is slower because an additional page mus be navigated. Default to False.
            skip_promoted_jobs=False,  # Skip promoted jobs. Default to False.
            limit=100,
        )
    ),
]

scraper.run(queries)
# Out:
# INFO:WDM:====== WebDriver manager ======
# INFO:WDM:Get LATEST chromedriver version for google-chrome 110.0.5481
# INFO:WDM:Driver [C:\Users\pc\.wdm\drivers\chromedriver\win32\110.0.5481\chromedriver.exe] found in cache
# INFO:li:scraper:('Using strategy AnonymousStrategy',)
# WARNING:li:scraper:("AnonymousStrategy is no longer maintained and it won't probably work. It is recommended to use an authenticated session, see documentation at https://github.com/spinlud/py-linkedin-jobs-scraper#anonymous-vs-authenticated-session.",)
# INFO:li:scraper:('Starting new query', "Query(query=Account Manager options=QueryOptions(limit=100 locations=['Worldwide'] optimize=False apply_link=False skip_promoted_jobs=False))")
# INFO:li:scraper:('Chrome debugger url', 'http://localhost:52727')
# INFO:li:scraper:('[Account Manager][Worldwide]', 'Opening https://www.linkedin.com/jobs/search?keywords=Account+Manager&location=Worldwide')
# INFO:li:scraper:('[Account Manager][Worldwide]', 'Trying first selectors set')
# INFO:li:scraper:('[Account Manager][Worldwide]', 'Trying second selectors set')
# INFO:li:scraper:('[Account Manager][Worldwide]', 'OK')
# INFO:li:scraper:('[Account Manager][Worldwide]', 'Starting pagination loop')
# INFO:li:scraper:('[Account Manager][Worldwide]', 'Found 25 jobs')
# INFO:li:scraper:('[Account Manager][Worldwide][1]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][2]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][3]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][4]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][5]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][6]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][7]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][8]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][9]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][10]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][11]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][12]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][13]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][14]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][15]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][16]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][17]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][18]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][19]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][20]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][21]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][22]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][23]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][24]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][25]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][26]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][27]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][28]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][29]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][30]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][31]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][32]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][33]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][34]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][35]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][36]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][37]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][38]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][39]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][40]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][41]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][42]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][43]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][44]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][45]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][46]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][47]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][48]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][49]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][50]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][51]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][52]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][53]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][54]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][55]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][56]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][57]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][58]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][59]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][60]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][61]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][62]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][63]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][64]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][65]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][66]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][67]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][68]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][69]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][70]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][71]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][72]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][73]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][74]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][75]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][76]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][77]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][78]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][79]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][80]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][81]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][82]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][83]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][84]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][85]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][86]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][87]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][88]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][89]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][90]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][91]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][92]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][93]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][94]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][95]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][96]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][97]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][98]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][99]', 'Processed')
# INFO:li:scraper:('[Account Manager][Worldwide][100]', 'Processed')
# [ON_END]

# %%
# Fired once for each successfully processed job
machine_learning = []
def on_data(data: EventData):
    machine_learning.append([data.job_id, data.title, data.company, data.description, ['Machine Learning Engineer']])


# Fired once for each page (25 jobs)
def on_metrics(metrics: EventMetrics):
    print('[ON_METRICS]', str(metrics))


def on_error(error):
    print('[ON_ERROR]', error)


def on_end():
    print('[ON_END]')


scraper = LinkedinScraper(
    chrome_executable_path=ChromeDriverManager().install(),  # Custom Chrome executable path (e.g. /foo/bar/bin/chromedriver) 
    chrome_options=None,  # Custom Chrome options here
    headless=True,  # Overrides headless mode only if chrome_options is None
    max_workers=1,  # How many threads will be spawned to run queries concurrently (one Chrome driver for each thread)
    slow_mo=7,  # Slow down the scraper to avoid 'Too many requests 429' errors (in seconds)
    page_load_timeout=70  # Page load timeout (in seconds)    
)

# Add event listeners
scraper.on(Events.DATA, on_data)
scraper.on(Events.ERROR, on_error)
scraper.on(Events.END, on_end)

queries = [
    Query(
        query='Machine Learning Engineer',
        options=QueryOptions(
            apply_link=False,  # Try to extract apply link (easy applies are skipped). If set to True, scraping is slower because an additional page mus be navigated. Default to False.
            skip_promoted_jobs=False,  # Skip promoted jobs. Default to False.
            limit=160,
        )
    ),
]

scraper.run(queries)
# Out:
# INFO:WDM:====== WebDriver manager ======
# INFO:WDM:Get LATEST chromedriver version for google-chrome 110.0.5481
# INFO:WDM:Driver [C:\Users\pc\.wdm\drivers\chromedriver\win32\110.0.5481\chromedriver.exe] found in cache
# INFO:li:scraper:('Using strategy AnonymousStrategy',)
# WARNING:li:scraper:("AnonymousStrategy is no longer maintained and it won't probably work. It is recommended to use an authenticated session, see documentation at https://github.com/spinlud/py-linkedin-jobs-scraper#anonymous-vs-authenticated-session.",)
# INFO:li:scraper:('Starting new query', "Query(query=Machine Learning Engineer options=QueryOptions(limit=160 locations=['Worldwide'] optimize=False apply_link=False skip_promoted_jobs=False))")
# INFO:li:scraper:('Chrome debugger url', 'http://localhost:52763')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide]', 'Opening https://www.linkedin.com/jobs/search?keywords=Machine+Learning+Engineer&location=Worldwide')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide]', 'Trying first selectors set')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide]', 'Trying second selectors set')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide]', 'OK')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide]', 'Starting pagination loop')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide]', 'Found 25 jobs')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][1]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][2]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][3]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][4]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][5]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][6]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][7]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][8]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][9]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][10]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][11]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][12]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][13]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][14]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][15]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][16]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][17]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][18]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][19]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][20]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][21]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][22]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][23]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][24]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][25]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][26]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][27]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][28]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][29]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][30]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][31]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][32]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][33]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][34]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][35]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][36]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][37]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][38]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][39]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][40]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][41]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][42]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][43]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][44]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][45]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][46]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][47]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][48]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][49]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][50]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][51]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][52]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][53]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][54]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][55]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][56]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][57]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][58]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][59]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][60]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][61]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][62]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][63]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][64]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][65]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][66]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][67]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][68]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][69]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][70]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][71]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][72]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][73]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][74]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][75]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][76]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][77]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][78]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][79]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][80]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][81]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][82]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][83]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][84]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][85]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][86]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][87]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][88]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][89]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][90]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][91]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][92]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][93]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][94]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][95]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][96]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][97]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][98]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][99]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][100]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][101]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][102]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][103]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][104]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][105]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][106]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][107]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][108]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][109]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][110]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][111]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][112]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][113]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][114]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][115]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][116]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][117]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][118]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][119]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][120]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][121]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][122]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][123]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][124]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][125]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][126]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][127]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][128]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][129]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][130]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][131]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][132]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][133]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][134]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][135]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][136]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][137]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][138]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][139]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][140]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][141]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][142]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][143]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][144]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][145]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][146]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][147]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][148]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][149]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][150]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][151]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][152]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][153]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][154]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][155]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][156]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][157]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][158]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][159]', 'Processed')
# INFO:li:scraper:('[Machine Learning Engineer][Worldwide][160]', 'Processed')
# [ON_END]

# %%
job_posting_matrix = software_developer + ux_designer + business_analyst + sales_analyst + product_manager + account_manager + machine_learning + marketing_analyst
job_posting_matrix
# Out:
# [['3503619612',
#   'Desenvolvedor de Software Jr - Low Code / No Code - Home Office',
#   'Unimed Grande Florianópolis',
#   'Sobre a UGF:\n\n\n\n\nSomos a maior cooperativa de saúde de Santa Catarina, há mais de 50 anos nos dedicamos a cuidar da saúde e do bem-estar das pessoas. Faça parte da equipe Unimed Grande Florianópolis e contribua para a qualidade e a eficiência de nossos serviços. Venha ser um UGFer!\n\n\n\n\nO que você fará:\n\n\n\n\nAtuar em todo o processo de desenvolvimento de produto, participando de equipes multidisciplinares. Codificar e automatizar testes, bem como contribuir para evolução de sistemas já existentes. Sugerir mudanças nos processos executados pela equipe, considerando aspectos relacionados a escalabilidade, performance, qualidade de código e arquitetura de software. Deverá manter-se atualizado quanto às tendências de mercado, em relação a novas tecnologias e metodologias utilizadas no desenvolvimento de produtos.\n\n\n\n\nPrecisamos que você tenha:\n\n\n\n\nEnsino Médio completo;\n\n\n\n\nDesenvolvimento de software;\n\n\n\n\nDesenvolvimento backend (JAVA, spring-boot);\n\n\n\n\nConhecimento das melhores práticas de desenvolvimento de software como: Clean code, Refactoring, SOLID, etc;\n\n\n\n\nConhecimento em banco de dados relacionais (postgres, mysql, etc);\n\n\n\n\nMetodologias Ágeis (Scrum).\n\n\n\n\nVocê irá se destacar se tiver:\n\n\n\n\nEnsino Superior cursando, preferencialmente em Ciências da computação ou Sistemas de informação;\n\n\n\n\nConhecimento em tecnologias voltadas para o front-end (javascript, html, css, frameworks).\n\n\n\n\nModelo de trabalho: Teletrabalho.\n\n\n\n\nRemuneração: R$ 5.940,48\n\n\n\n\nPorque você vai adorar trabalhar com a gente:\n\n\n\n\nAuxílio educação para colaboradores com 1 ano de empresa;\nGinástica Laboral;\nVale refeição e/ou alimentação (R$ 800,00)\nFornecemos ajuda de custo ($) para o trabalho remoto;\nAuxílio creche;\nVale transporte;\nPlano de saúde para quem residir na Grande Florianópolis e quem reside fora da Grande Florianópolis na modalidade Home office, oferecemos o auxílio saúde;\nPlano odontológico;\nFolga de aniversário;\nPlano de carreira, cargos e salário;\nPrograma Psicologia Viva (Psicoterapia Online);\nGympass.\n\n\n\n\nHorário de trabalho: De segunda a sexta das 08:00 às 18:00.\n\n\n\n\nTemos orgulho de nossos talentos e de promover uma cultura inclusiva. Por isso, consideramos todas as candidaturas para as nossas vagas sem distinção de etnias, raça, cor, religião, gênero e identidade de gênero, nacionalidade, deficiência, orientação sexual, idade, cultura etc.\nShow more ',
#   ['Software Developer']],
#  ['3489403427',
#   'Software Engineer',
#   'LinkedIn',
#   "The ideal candidate will help build, maintain, and troubleshoot, the company's rapidly expanding infrastructure. They will work alongside other engineers to ensure highest levels of performance and ability, and manage any problems that arise. \xa0\n\n\xa0\n\nResponsibilities\nManage and monitor installed systems\nTest and maintain operation systems\nMonitor application performance\n\n\n\n\nQualifications\n\nBachelor's degree in Computer Science or related field\nExperience in configuring, monitoring and troubleshooting systems\nStrong scripting and technical skills\n\nShow more ",
#   ['Software Developer']],
#  ['3490979195',
#   'Software Engineer',
#   'PayPal',
#   "At PayPal (NASDAQ: PYPL), we believe that every person has the right to participate fully in the global economy. Our mission is to democratize financial services to ensure that everyone, regardless of background or economic standing, has access to affordable, convenient, and secure products and services to take control of their financial lives.\n\n\n\n\nJob Description Summary:\n\n\n\n\nAbout PayPal We believe that every person has the right to participate fully in the global economy. Our mission is to democratize financial services to ensure that everyone, regardless of background or economic standing, has access to affordable, convenient, and secure products and services to take control of their financial lives. P2P team is looking for an experienced engineer with solid backend development skills to design and build the right P2P products. Your primary focus will be to work on product requirements and undergo the entire SDLC process to create highly available, highly scalable and high quality products.\n\n\n\n\nJob Description:\n\n\n\n\nYour Day to Day Activities:\n\n\n\n\nCoding, testing and debugging programs according to computer engineering specifications\nModifying, expanding and updating applications\nDeveloping software prototypes\nWorking with quality assurance to develop software test plans\nDeploying code in LIVE\nMonitoring applications in LIVE and solving LIVE issues\nDocumentation skills to articulate solution design and implementation plans\n\n\n\n\n\n\nWhat you need to bring to the table:\n\n\n\n\nProgramming skills in Java\nExposure to additional languages and frameworks such as C#/C++, HTML, Microsoft. NET, and SQL server.\n\n\n\n\n\n\nEducation\n\n\n\n\nBachelor's degree in computer science or similar field but may accept two-year technical degree if combined with several years of practical experience\n\n\n\n\nExperience\n\n\n\n\nLevel III - Advanced: 6-8 years\n\n\n\n\nOur Benefits:\n\n\n\n\nAt PayPal, we’re committed to building an equitable and inclusive global economy. And we can’t do this without our most important asset—you. That’s why we offer benefits to help you thrive in every stage of life. We champion your financial, physical, and mental health by offering valuable benefits and resources to help you care for the whole you.\n\n\n\n\nWe have great benefits including a flexible work environment, employee shares options, health and life insurance and more. To learn more about our benefits please visit https://www.paypalbenefits.com\n\n\n\n\nWho We Are:\n\n\n\n\nTo learn more about our culture and community visit https://about.pypl.com/who-we-are/default.aspx\n\n\n\n\nPayPal has remained at the forefront of the digital payment revolution for more than 20 years. By leveraging technology to make financial services and commerce more convenient, affordable, and secure, the PayPal platform is empowering more than 400 million consumers and merchants in more than 200 markets to join and thrive in the global economy. For more information, visit paypal.com.\n\n\n\n\nPayPal provides equal employment opportunity (EEO) to all persons regardless of age, color, national origin, citizenship status, physical or mental disability, race, religion, creed, gender, sex, pregnancy, sexual orientation, gender identity and/or expression, genetic information, marital status, status with regard to public assistance, veteran status, or any other characteristic protected by federal, state or local law. In addition, PayPal will provide reasonable accommodations for qualified individuals with disabilities. If you are unable to submit an application because of incompatible assistive technology or a disability, please contact us at paypalglobaltalentacquisition@paypal.com.\n\n\n\n\nAs part of PayPal’s commitment to employees’ health and safety, we have established in-office Covid-19 protocols and requirements, based on expert guidance. Depending on location, this might include a Covid-19 vaccination requirement for any employee  ...
#   ['Software Developer']],
#  ['3507663809',
#   'Junior Software Developer (Web/Front-End)',
#   'Samsung Brasil',
#   'Position Summary\n\n\n\n\nDevelop a differentiated system by understanding the hardware architecture of a system and optimize its design.\nDevelop an optimal system by understanding and designing a system’s software architecture and subsystems.\nDevelop an optimal system which integrates service and application by applying system software to system hardware.\n\n\n\n\nRole And Responsibilities\n\n\n\n\n[System architecture] Help to design an optimal system taking various factors into consideration like performance, expandability, expense, and electricity consumption. (Considering both hardware and software)\n[Designing system hardware] Help to design key function block, interface, and layout based on features of hardware components and requirements.\n[System strategy] Help to establish a system strategy, discover a new technology, and develop and follow technological standards.\n[System software] Help to analyze requirements and understand a development framework. Make a design for planning, development, inspection, maintenance, and management when developing an application.\n[System improvement] Help to achieve system innovation by monitoring it and finding areas to be improved.\n\n\n\n\nSkills And Qualifications\n\n\n\n\nHas substantial understanding on the job and applies knowledge and skills to complete a wide range of tasks\nWorks on assignments that are moderately difficult, requiring judgment in resolving issues or in making recommendations\nNormally receives little instruction on everyday work and general instructions on newly introduced assignments\nTypically requires a minimum 3 years of related experience since TB1.\n\n\n\n\nOpportunity in Campinas/SP.\n\n\n\n\nConfidential and proprietary information obtained by the candidate during his employment history with other companies must be kept as such (Confidential & Proprietary) throughout the selection process and must not be questioned in any way.\n\n\n\n\nPlease visit Samsung membership to see Privacy Policy, which defaults according to your location. You can change Country/Language at the bottom of the page. If you are European Economic Resident, please click here.\nShow more ',
#   ['Software Developer']],
#  ['3497871312',
#   'Software Engineer',
#   'Oracle',
#   'Want to come join the Oracle Health Data & Analytics Team?\n\n\n\n\nWe are looking for developers to help hospitals improve the quality of patient care by developing regulatory based reports. Developers with knowledge in databases, SQL, and reporting should apply.\n\n\n\n\nJob description:\n\n\n\n\nAs a member of the Quality Measures mPages regulatory team, you will use basic knowledge of software architecture to perform tasks associated with developing, debugging or designing software applications according to provided design specifications. Build enhancements within an existing software architecture.\n\n\n\n\nWork involves some problem solving with assistance and guidance in understanding and applying company policies and processes. Gaining competence in own area and acquiring a higher level understanding of role, processes and procedures. BS degree or equivalent experience relevant to functional area. 0-2 years of previous software engineering or related experience.\n\n\n\n\nResponsibilities:\n\n\n\n\nResponsibilities of a Software Developer on the Quality Measures mPages regulatory team will include development of CCL and JavaScript applications based upon government specifications and company procedures. Additionally the developer will provide support of the solution clients through their applications and submissions of their regulatory reporting to government agencies.\n\n\n\n\nDisclaimer:\n\n\n\n\nCertain US customer or client-facing roles may be required to comply with applicable requirements, such as immunization and occupational health mandates.\n\n\n\n\nRange and benefit information provided in this posting are specific to the stated location(s)\n\n\n\n\nCalifornia Pay Range: from $72,300 to $151,600 per annum. May be eligible for bonus and equity.\n\nColorado Pay Range: from $60,700 to $136,400 per annum. May be eligible for bonus and equity.\n\nNew York City Pay Range: from $73,500 to $144,000 per annum. May be eligible for bonus and equity.\n\nWashington Pay Range: from $78,100 to $144,000 per annum. May be eligible for bonus and equity.\n\n\n\n\nOracle maintains broad salary ranges for its roles in order to account for variations in knowledge, skills, experience and market conditions, as well as reflect Oracle’s differing products, industries and lines of business.\n\nCandidates are typically placed into the range based on the preceding factors as well as internal peer equity.\n\n\n\n\nOracle offers a comprehensive benefits package which includes the following:\n\n1. Medical, dental, and vision insurance, including expert medical opinion\n\n2. Short term disability and long term disability\n\n3. Life insurance and AD&D\n\n4. Supplemental life insurance (Employee/Spouse/Child)\n\n5. Health care and dependent care Flexible Spending Accounts\n\n6. Pre-tax commuter and parking benefits\n\n7. 401(k) Savings and Investment Plan with company match\n\n8. Flexible paid time off (unlimited or accrued vacation and sick leave)\n\n9. Paid parental leave\n\n10. Employee Stock Purchase Plan\n\n11. Adoption assistance\n\n12. Financial planning and group legal\n\n13. Voluntary benefits including auto, homeowner and pet insurance\n\n\n\n\nEmail of Internal Contact\n\nShow more ',
#   ['Software Developer']],
#  ['3497424706',
#   'Junior Software Developer',
#   'PersonalSoft',
#   'Únete a nuestro equipo PersonalSoft. Somos una compañía con más de 20 años de experiencia en desarrollo de software, servicios de analítica, automatización de procesos, con presencia en Bogotá, Medellín, Panamá, El Salvador, República Dominicana y EE.UU.\n\n\n\n\n¿Qué buscamos?\n\n\n\n\nUn Ingeniero de Software Junior con muchas ganas de crecer y aprender dentro de nuestra compañia.\nCon conocimiento basicos en: Base de Datos, ETL´s, lenguaje de programación PL/SQL, Java, C++.\nEcosistema de nube: Perl, Python, Ruby, .NET; etc.\nBuen nivel de inglés, en escritura y conversación.\n\n\n\n\nFunciones y Responsabilidades\n\n\n\n\nIngenieros en Desarrollo de Software Jr, o carrera afín, sin experiencia, pero con sólidos conocimientos en todo el ciclo del desarrollo de software en metodologías ágiles (análisis, diseño, construcción, pruebas e implementación).\n\n\n\n\nHabilidades blandas y tecnicas\n\n\n\n\nAutodidacta\nTrabajo en equipo\nTrabajo colaborativo\nConfiables\nComprometidos\nResponsables con el trabajo.\n\n\n\n\nRequisitos mínimos\n\n\n\n\nIngenieros en Desarrollo de Software Jr, o carrera afín, sin experiencia.\nCon conocimiento basicos en: Base de Datos, ETL´s, lenguaje de programación PL/SQL, Java, C++.\nEcosistema de nube: Perl, Python, Ruby, .NET; etc.\nBuen nivel de inglés, en escritura y conversación.\nShow more ',
#   ['Software Developer']],
#  ['3497654432',
#   'Software Engineer',
#   'Illuma',
#   'We are looking for a highly motivated Software Engineer to work within our technical team, helping to drive efficiency through innovative solutions. Technology is central to our continued growth and you will be supported by and work alongside other engineers.\n\nThis is a fantastic opportunity to work in a truly dynamic company under inspiring leadership, where you will have the opportunity to work on some of the most exciting technologies in the sector. On a day to day basis you will be responsible for and take the lead on a number of projects where you will use your analytical skills to understand the given brief and foresee any technical challenges that may arise. Alongside others you will be responsible for data management, data analysis, data visualisation and interface development.\n\nRequirements\n\nKey Responsibilities and Accountabilities\n\nUse a combined knowledge of computer science and applications, modelling statistics, analytics and maths to solve problems\nDevelop backend software solutions by studying information needs, analysing user requirements, and studying systems flow, data usage, and work processes\nWrite and test code, refining and rewriting it as necessary and communicate with any programmers involved in the project\nImprove and develop existing programs by analysing and identifying areas for modification\nIntegrate existing software products and get incompatible platforms to work together\nMaintain systems by monitoring and correcting software defects\nSift and analyse data from multiple angles, looking for trends and insights that highlight problems or opportunities\nBrainstorm for new ideas and technologies to improvement development delivery\nContinually update technical knowledge and skills\nFollow all best practices and procedures as established by company\n\n\nKnowledge, Skills And Experience\n\n2:1 degree or higher from a top university in Computer Science, Software Engineering or related area of study\nExcellent written and spoken English\nExperience with software development lifecycle, from conception, architecture definition, detailed design, scoping, planning, implementation, testing to documentation, delivery and maintenance\nProficiency in Python backend software development\nExperience with version control system: Git (Github & Bitbucket)\nExperience with Linux infrastructures, database SQL (MySQL, PostgreSQL), CI/CD tools, shell scripting\nExperience with Virtualisation (e.g. Docker), configuration management (Ansible, AWS CloudFormation), access control/security\nCloud Service and distributed systems: Amazon Web Echo-System, Google Cloud Platform\nWeb development experience, such as HTML, CSS, JavaScript, Flask, Django, is preferable\nKnowledge & experience of machine learning, data analysis and data visualisation are preferable\nKnowledge & experience with digital advertising (e.g. demand-side platforms, sell-side platforms, Ad exchanges, etc) are preferable\nUp-to-date on latest industry trends; able to articulate trends and potential clearly and confidently\n\n\nBenefits\n\n25 days holiday plus bank holidays\nPrivate medical insurance (with half price gym membership)\nPension\nTeam socials, stocked fridge, snacks\nWe operate a Hybrid working model with initially the opportunity to work remotely for up to one day a week increasing to two days after successful probation period.\nShow more ',
#   ['Software Developer']],
#  ['3514254707',
#   'Jr./Mid-Level Software Engineer (Remote)',
#   'Staffingly',
#   'In this position, you will be working with software control and data processing systems for optical ground systems and radio antennas. You will be responsible for supporting Satellite Laser Ranging (SLR) and Very Long Baseline Interferometry (VLBI) operations, maintenance, test and integration of upgrades for the NASA Space Geodesy Network (NSGN) Data Operations Center (DOC).\n\nResponsibilities will include:\n\nMonitor data reception, processing, quality control, and delivery to the ILRS data centers.\nPrepare data reports for SLR engineering tests.\nDevelop code in accordance with applicable requirements documentation.\nDevelop and execute test plans for software system verification and acceptance and develop required documentation.\nSupport the integration of hardware and software systems and generation of related documentation.\nSupport software maintenance services which may include problem troubleshooting, software update/installation, and/or modification of system software.\nIdentify design alternatives and performing trade studies for system upgrades related to unsupported software and obsolete hardware.\nProvide support for legacy Linux systems and software, using Perl, C++, GO or Python as well as legacy Fortran utilities.\nDevelop and execute software test plans and procedures, to include verification/validation of operational software.\nPerform duties in accordance with all systems engineering and configuration management policies and procedures.\n\n\nREQUIRED EXPERIENCE:\n\nBS degree in Computer Science, Math, Engineering or other related technical field and 1+ years of experience in software development and engineering\nExperience with Perl and C++ programming languages, as well as Bash scripting\nExperience with Oracle databases for data storage and retrieval\n\n\nOther rewards may include annual bonuses, short- and long-term incentives, and program-specific awards. In addition, we provide a variety of benefits to employees.\nShow more ',
#   ['Software Developer']],
#  ['3500262155',
#   'Ingeniero de software Frontend',
#   'Mercado Libre',
#   'En Mercado Libre estamos democratizando el comercio, el dinero y los pagos en América Latina.\n\nTecnología es la esencia de nuestro producto. Nuestros equipos de desarrollo, arquitectura, base de datos, user experience, seguridad informática y data & analytics co-crean y son responsables de la plataforma líder de e-commerce de América Latina y de uno de los sitios de mayor tráfico en todo el mundo. En una industria que se reinventa día a día, nuestros equipos son reconocidos por su visión y liderazgo. Desde aplicaciones móviles a machine learning, nuestra innovación tiene un claro foco: simplificarle la vida a quien utiliza nuestros productos.\n\nTenemos un desafío para quienes:\n\nVibran energía emprendedora: se mueven por la curiosidad, nunca se rinden y se enfocan en superar sus propios límites.\nDan el máximo porque les gusta trabajar con compromiso y dedicación.\nViven los cambios como oportunidades y aprenden de sus errores.\nLa excelencia y la ejecución son claves en su forma de hacer las cosas.\nPromueven el buen clima, aportan alegría y diversión.\nSaben cómo construir con otras personas y disfrutan trabajando en equipo.\n\nImagínate emprendiendo proyectos desafiantes, dinámicos e innovadores y siendo responsable de:\n\nParticipar del ciclo completo de desarrollo de producto desde el análisis, prototipado y pruebas con usuarios hasta la mejora continua de las soluciones.\nConstruir sistemas de frontend eficientes y reutilizables.\nColaborar en la generación de nuevos productos, junto a profesionales de diseño y desarrollo de software.\nIdentificar y comunicar las mejores prácticas para la ingeniería de frontend, formando parte del diseño y revisión del código.\n\nRequisitos:\n\nSer profesional de Ingeniería en Sistemas o carreras afines.\nPoseer 2 años de experiencia de trabajo en frontend en ambientes de alto desempeño.\nContar con experiencia de trabajo con tecnologías web abiertas como JavaScript, HTML y CSS.\nTener experiencia en la utilización de NodeJS, Express, React, Sass, WPO y SEO.\n\nTe proponemos:\n\nSer parte de una compañía con espíritu emprendedor en la que nos encanta pensar en grande y a largo plazo.\nSer protagonista de tu desarrollo en un ambiente de oportunidades, aprendizaje, crecimiento, expansión y proyectos desafiantes.\nCompartir y aprender en equipo junto a grandes profesionales y especialistas.\nUn excelente clima de trabajo, con todo lo necesario para que vivas una gran experiencia. :)\n\n\u200b\u200b\u200b\u200b\u200b\u200b\u200bEn Mercado Libre trabajamos para promover una cultura inclusiva, que busca la equidad y valora las diferentes perspectivas. Esto se traduce en género, religión, personas con discapacidad, LGBTQ+, etnia y diversidad de experiencias. Trabajamos todas nuestras búsquedas con base en esta premisa. ¡Súmate a nuestro equipo!\n\nShow more ',
#   ['Software Developer']],
#  ['3503231568',
#   'DESARROLLADOR DE SOFTWARE',
#   'Cajasan',
#   'Habilidad en programación y desarrollo de software backend y frontend Análisis y desarrollo de aplicaciones web Mejora y desarollo de nuevas utilidades para proyectos de software actuales Desarrollo de nuevas aplicaciones Uso de PHP, Java Script, VUE, HTML, jasper report, framework.\n\n\n\n\nHabilidad en programación y desarrollo de software backend y frontend Análisis y desarrollo de aplicaciones web Mejora y desarollo de nuevas utilidades para proyectos de software actuales Desarrollo de nuevas aplicaciones Uso de PHP, Java Script, VUE, HTML, jasper report, framework.\nShow more ',
#   ['Software Developer']],
#  ['3490350851',
#   'Software Engineer-Sunnyvale',
#   'Alibaba Group',
#   '‧ Create innovative technology to enhance storage system scalability, reliability and availability\n\n‧ Design, develop and test advanced cloud-scale data services\n\n‧ Deploy, manage and diagnose large-scale software systems\n\n‧ Develop practical solutions to tackle the engineering challenges of complex distributed system software\n\n\n\n\nQualifications\n\n‧ Track record in research and development of storage, file system, data and related systems technology\n\n‧ Experience in development of cloud infrastructure\n\n‧ Creativity, ability to think outside the box and willingness take on new challenges\n\n‧ Passion for technology\n\n‧ Proficiency in C/C++ programming\n\n‧ Experience with Python or other scripting languages\n\n‧ Familiarity with commonly used algorithms, data structures, network programming and multi-threaded programming\n\n‧ Excellent communication skills\n\n‧ Positive work spirit\n\n\n\n\nThe pay range for this position at commencement of employment is expected to be between $146,400/year and $240,000/year. However, base pay offered may vary depending on multiple individualized factors, including market location, job-related knowledge, skills, and experience.\n\n\n\n\nIf hired, employee will be in an “at-will position” and the Company reserves the right to modify base salary (as well as any other discretionary payment or compensation program) at any time, including for reasons related to individual performance, Company or individual department/team performance, and market factors.\n\nShow more ',
#   ['Software Developer']],
#  ['3503827551',
#   'Software Engineer (Junior OR Mid-Level Preferred) - Hybrid',
#   'Captivation',
#   'Annual Salary: $135,000 - $215,000 (depends on experience level)\n\nUp to 20% 401k contribution (no matching required)\n\nBuild Something to Be Proud Of.\n\nCaptivation Software has built a reputation on providing customers exactly what is needed in a timely manner. Our team of engineers take pride in what they develop and constantly innovate to provide the best solution. Captivation Software has an immediate need for a Software Engineer to support our customer.\n\nPosition is eligible for up to 20% telework.*\n\n\nRequirements\n\nSecurity Clearance:\n\nMust currently hold a Top Secret / SCI U.S. Government security clearance w/ a Favorable Polygraph, therefore all candidates must be a U.S. citizen.\n\n\nRequired Skills:\n\nBachelor’s degree in Computer Science or related discipline is required.\nShall have experience as a Software Engineer in software development/engineering, including requirements analysis, software development, installation, integration, evaluation, enhancement, maintenance, testing, or problem diagnosis/resolution. The individual must be able to communicate directions and provide guidance to junior programmer/analysts, as required.\nShall have a firm grasp of modern computer programming and development of application software for complex systems and software testing.\nShall have extensive experience in planning and accomplishing goals and complicated tasks and providing consultation on complex projects as top-level contributor or specialist.\nShall have experience developing solutions integrating or extending FOSS/COTS products.\nShall have demonstrated technical writing skills and have generated technical documents in support of a software development project.\nShall have experience on the design and development of at least one Object Oriented system.\nUnix/Linux environments (bash, scripting, ftp, .sh); bare metal\nJava, Java Spring Frameworks, general open source Java libraries\nRESTful Web/Reactive Services (Java/Spring/SpringBoot)\nCloud-based streaming analytic environments with big data ingestion/processing (e.g., Heron, Storm, Flink)\n\n\nDesired Skills:\n\nCloud-based data queuing, batching, and messaging (e.g., Kafka Messaging, Kafka Streams, NiFi)\nContainerization of services via Docker (e.g., DockerHub/Harbor, YAML files)\nDocker orchestration software (e.g., Kubernetes)\nSQL, NoSQL, and caching databases (e.g., MySQL, Cassandra, ElasticSearch, Redis)\nAutomated build/deployment environments - production, staging, development (e.g., Maven, Jenkins, Git)\nAgile development practices (e.g., Scrum/Sprints, Jira/Confluence)\neVo and UWE environments\n\n\nOther optional technical skills may include some of the following:\n\nExperience with distributed monitoring/logging software (e.g., Prometheus, Grafana, Kabana)\nExperience with Geo/Mapping technologies (e.g., WMS, WKT, GeoTools)\nUnderstanding of customer data feeds/types/formats\nUnderstanding of customer AEA/MWS and other corporate services\nUnderstanding of customer certification, compliance and policy topics\nUnderstanding of customer networks (protection levels, etc.)\nUnderstanding of customer streaming and storage corporate services\n\n\nBenefits\n\nAnnual Salary: $135,000 - $215,000 (depends on experience level)\nUp to 20% 401k contribution (no matching required)\nAbove market hourly rates\n$3,000 HSA Contribution\n5 Weeks Paid Time Off\nCompany Paid Employee-Only Medical / Dental / Vision Insurance / Life Insurance / Short-Term & Long-Term Disability / AD&D\nShow more ',
#   ['Software Developer']],
#  ['3497730227',
#   'Graduate Software Developer Intern',
#   'Virtru',
#   '\\\n\nThis is a paid Summer 2023 Internship. This is a temporary, full-time internship. Candidates must be able to commit to a 10 week program.\n\nAbout Virtru:\n\nVirtru is a leading data protection provider backed by some of the foremost venture capital firms in Silicon Valley and the Mid-Atlantic region, including Iconiq Capital, Bessemer Venture Partners, Foundry Capital, and Tiger Global. Today, more than ever, data demands respect, and that\'s why Virtru is committed to changing the rules for data privacy. At Virtru, we equip our customers to take granular control of their data—everywhere it\'s shared—through end-to-end encryption for Google, Microsoft, and other data sharing platforms. Our market-leading portfolio of data encryption and privacy enhancing applications are remarkably easy to use, fast to implement, affordable for all, and built on the Trusted Data Format (TDF) open standard.\n\nAt Virtru, our motto is "Respect the people. Respect the data." Respecting data to us means keeping it secure and protected at all times across its entire lifecycle. We firmly believe that when you respect data, you\'re demonstrating respect for the people who own that data.\n\nWorking at Virtru, you\'ll be inspired by colleagues who are passionate about the work they do. We are dedicated to creating an atmosphere that sparks creativity, connection, and professional growth while empowering each other to do our best work. We\'re building something special at Virtru. We hope you consider joining our team and helping us create a brighter future for data privacy.\n\nTeam & Position Details:\n\nAs a Graduate Software Developer Intern on our H3 (Horizon) team, you will be working with our leading System Architect to heavily research and document new directions for our R&D function, completing quality oriented tasks and personally selected research.\n\nWe are seeking a graduate level intern engineer who is dedicated to solving interesting problems using high quality software implementations using (but not limited to) Java, Go and Python. The ideal candidate will have a natural passion for digital privacy, software development, and great user experiences. We encourage curiosity and have a culture that encourages growth. As an Engineer at Virtru, you will be on the cutting edge of Zero-Trust - the future of data and service protection!\n\nAs a Graduate Software Developer Intern, your responsibilities will include:\n\nDefine the research problem: Identify challenges our engineering team is facing. Learn more about Virtru\'s initiatives and department goals (current focus on protecting data in use via secure digital data clean rooms) through internal discussions and discovery with your manager\nConduct a review: Collect internal existing knowledge and developments external to Virtru\nDevelop your research hypotheses and methodology: Based on the research problem and review, develop hypotheses that can be tested and a process for experimentation\nRun your tests, collect data and analyze: Innovate, learn fast, repeat!\nDraw Conclusions: Develop suggestions, share with your team, document and prepare to present!\nCommunicate results: Communicate the research findings through reports, presentations, or publications internal and external to Virtru\n\n\nSkills and Tools that will help you thrive in this role:\n\nFamiliarity with the Software development process from writing code for personal projects, coding competitions, or research\nLanguages: Python, Java, Go-lang\nInfrastructure: AWS using Terraform, Ansible, Docker, Google Cloud Platform\nFrameworks / Tooling: Kubernetes, OPA\nFamiliarity with data structure and algorithms\nMust be a self-starter who works well independently on assigned tasks and products\nDesire to learn and grow with a close-knit engineering team\nCurrently pursuing or completed advanced degree in Computer Science or related field\n\n\nVirtruvian qualities that will set you up for success:\n\nThinking outside of the box t ...
#   ['Software Developer']],
#  ['3490976113',
#   'Software Engineer 2',
#   'Intuit',
#   'Come join the "Intuit Monetization Service and Experiences(MSE)" as a "Software Engineer 2". This team is responsible for all aspects of the Intuit Revenue Platform (IRP), including product team onboarding, the accuracy of customers’ bills and ease of bill management, increasing efficiencies in our billing and commerce systems, retiring legacy billing systems, and building a robust SOX-compliant revenue recognition system.\n\n\n\n\nOverview:\n\nSuccessful delivery of high quality web or mobile software (requirements, design, code, documentation, etc.)\nRoughly 80-95% hands-on coding\nContribute to early quality activities, including peer reviews of estimates, designs and code\nResolve defects/bugs during QA testing, pre-production, production, and post-release patches\nPartner effectively with all team members to deliver against commitments\nWork cross-functionally with various Intuit teams: product management, QA/QE, various product lines, or business units to drive forward results\nCommitment to team success and positive team dynamics\nPassion for growing and applying technical skills in service to customers\nExperience with Agile Development, SCRUM, and/or Extreme Programming methodologies\n\n\n\n\nResponsibilities:\n\nAt least 2+ years experience developing web, software, or mobile applications\nBS/MS in computer science or equivalent work experience.\nStrong HTML and JavaScript (ReactJS, Relay, GraphQL/Apollo) skills\nStrong CSS experience. Strong User Interfacing knowledge\nStrong experience in one of the leading Javascript Frameworks\nStrong experience in back end programming in Java / Java EE, Springboot\nExperience in AWS and Kubernetes an added advantage\nSolid communication skills: Demonstrated ability to explain complex technical issues to both technical and non-technical audiences\nStrong understanding of the Software design/architecture process\nExperience with unit testing & Test Driven Development (TDD)\nAbility to perform end to end engineering – design, development, testing and deployment\n\n\n\n\nPreferred Experience:\n\nExperience developing, maintaining, and innovating large scale, consumer facing web or mobile applications\nExperience with social, mobile, cloud/SaaS, big data, or analytics\nFamiliar with the development challenges inherent with highly scalable and available web applications\nExperience with various, modern web framework\nImagine a career where your creative inspiration can fuel BIG innovation. Year-over-year, Intuit has been recognized as a best employer and is consistently ranked on Fortune\'s â\x80œ100 Best Companies To Work Forâ\x80 and Fortune Worldâ\x80™s â\x80œMost Admired Software Companies lists. Immerse yourself in our award winning culture while creating breakthrough solutions that simplify the lives of consumers and small businesses and their customers worldwide.\nIntuit is expanding its social, mobile, and global footprint with a full suite of products and services that are revolutionizing the industry. Utilizing design for delight and lean startup methodologies, our entrepreneurial employees have brought more than 250 innovations to market -- from QuickBooksÂ®, QuickenÂ®, and TurboTaxÂ®, to GoPayment, Mint.com, big data, cloud (SaaS, PaaS) and mobile apps. The breadth and depth of these customer-driven innovations mean limitless opportunities for you to turn your ingenious ideas into reality at Intuit.\nDiscover what itâ\x80™s like to be part of a team that rewards taking risks and trying new things. Itâ\x80™s time to love what you do! Check out all of our career opportunities at: http://jobs.intuit.com. Intuit is an Equal Opportunity Employer.\n\nShow more ',
#   ['Software Developer']],
#  ['3499598455',
#   'Software Engineer',
#   'Infleqtion',
#   "Infleqtion (ColdQuanta/Super.tech) is a global quantum technology company solving the world’s most challenging problems. The company harnesses quantum mechanics to build and integrate quantum computers, sensors, and networks. From fundamental physics to leading edge commercial products, Infleqtion enables “quantum everywhere” through our ecosystem of devices and platforms. We are recruiting for a Software Engineer.\n\nLocation\n\nInfleqtion has 5 office locations, operating out of Boulder/Louisville, CO; Madison, WI; Chicago, IL; London, UK; and Melbourne, AU. This position is a full-time, hybrid position which will be located in our Louisville, Colorado office.\n\nPosition Summary\n\nThe newly hired engineer will collaborate on current research projects and support development of new concepts and approaches for future investigations.\n\nJob Responsibilities\n\nThe duties and responsibilities outlined below include essential functions of the role. Depending on business needs, this role may perform a combination of some or all of the following duties. Duties, responsibilities, and activities may change, or new ones may be assigned.\n\nGather requirements by communicating with researchers, end users, and team members\nManage project priorities, deadlines, and deliverables\nDesign, develop, test, deploy, maintain, and improve software\nCommunicate your software designs and tools through documentation and design reviews\nCollaborate with software engineers, physicists, and product owners to design and develop software solutions\n\n\nRequirements\n\nKnowledge, Skills and Abilities (KSAs)\n\nBachelor’s degree in engineering, computer science or related field and minimum 2 years' work experience; or 5 years' work experience without a Bachelor’s degree\nHigh level of skill and experience with Python\nExperience with at least one compiled systems language, like Rust, C/C++, etc\nSkilled in typical software engineering disciplines: testing, error-handling, readability, documentation, general code health, etc.\nProficient working in a Linux environment\nProficient with data structures and algorithms\nExperience with embedded systems is preferred, but not required\nKnowledge of quantum mechanics is NOT required, but successful applicants should be willing to learn\nDemonstrated ability to effectively share information with technical and non-technical staff\nDemonstrated ability to learn new and complex topics quickly\nDemonstrated ability to work and communicate with all levels of an organization; Professional-level communication skills, including verbal, written, and presentation skills\nDemonstrated ability to work comfortably in a highly collaborative, cross-functional, team-oriented, and matrixed environment\nDesire and demonstrated ability to thrive and produce results in a fluid, dynamic, and fast-paced environment\nPassion for solving complex problems and challenges in a highly technical and scientific environment\nAbility to travel domestically and (potentially) internationally up to 10%\nThis role requires that you do not require sponsorship or a work visa transfer\n\n\nThis position may require access to information protected under U.S. export control laws and regulations, including the Export Administration Regulations (EAR) and the International Traffic in Arms Regulations (ITAR). Please note that any offer for employment may be conditioned on authorization to receive software or technology controlled under these U.S. export control laws and regulations without sponsorship for an export license\n\nBenefits\n\nThe salary range for this role is $100,000 - $120,000.\n\nIn addition to your base compensation, we offer a generous Total Rewards program which includes:\n\n100% company paid Employee coverage for Medical, Dental, Vision, and Short/Long Term Disability insurance programs\nEmployer funded Health Savings Account\nUnlimited Paid Time Off\n401(k) safe harbor contribution\nCompany paid Life and AD&D Insurance\nFlexible Sav ...
#   ['Software Developer']],
#  ['3476215994',
#   'Jr Software Developer',
#   'Applycup Hiring Solutions',
#   'Exp: 0-1 years; Jr Software Developer Pune, Maharashtra Skills\n\nFresher Job Description\n\nJob Description- Excellent knowledge of language in either Java / .net / PHP / Python Education in BE / B.tech / BCA / BCS / Passing year 2020 Good Communication Skill Candidate Profile\n\nSalary Range\n\nNot disclosed\nShow more ',
#   ['Software Developer']],
#  ['3503182763',
#   'Junior Software Developer',
#   'Tracsis plc',
#   "What you’ll do?\n\nWe’re looking for a Junior Software Developer who will join our development team at Tracsis Rail Consultancy. Day to day you’ll support our front and back end developers. We want to support you as you develop a broad understanding of both roles.\n\nWe use C# for the backend and Python for the front end, whilst we absolutely support any development needed if you have an understanding of these languages or anything similar that will set you up for success.\n\nYou’ll join a team of 10 lead by Mark. While this role is remote, we have an office in Derby that you’ll always be welcome at and the team have regular online meeting sessions, daily stand ups, and fortnightly training sessions on skills to ensure there is collaboration.\n\nWho you’ll be?\n\nWe want to make sure you’re set for success so the key skills we’re looking for in the role are below. We know not everyone ticks all the boxes and we’ll provide training on some of the areas if you’re the right person for the role.\n\nSomeone with a passion to learn\nSelf-motivated and capable of getting things done\nKeen problem solver\nPrevious experience working in tech (although we don't mind what tech you’ve worked with)\nGreat attention to detail.\n\nWhat We’ll Give You\n\nYou’ll join a diverse team with a friendly and relaxed culture. We encourage collaboration both with colleagues and customers.\n\nWe have a supportive environment where innovation, fresh ideas and creative solutions are encouraged and shared.\n\nWe have a clear career path moving from junior developer into developer, senior then principle with learning and coaching offered at each stage. That been said we also encourage you to follow your passion and there are plenty of options to move diagonally, horizontally etc. For us it is about encouraging you to continuously grow and develop.\n\nAbout Us\n\nWe are a technology company and a leading provider of software and hardware products, and consultancy services for the rail industry. We also provide data capture, data analytics, and event transport planning and management services across the wider transport industry.\n\nTechnology makes it possible; people make it happen.\nShow more ",
#   ['Software Developer']],
#  ['3499599364',
#   'Software Engineer',
#   'Infleqtion',
#   "Infleqtion (ColdQuanta/Super.tech) is a global quantum technology company solving the world’s most challenging problems. The company harnesses quantum mechanics to build and integrate quantum computers, sensors, and networks. From fundamental physics to leading edge commercial products, Infleqtion enables “quantum everywhere” through our ecosystem of devices and platforms. We are recruiting for a Software Engineer.\n\nLocation\n\nInfleqtion has 5 office locations, operating out of Boulder/Louisville, CO; Madison, WI; Chicago, IL; London, UK; and Melbourne, AU. This position is a full-time, hybrid position which will be located in our Madison, Wisconsin office.\n\nPosition Summary\n\nThe newly hired engineer will collaborate on current research projects and support development of new concepts and approaches for future investigations.\n\nJob Responsibilities\n\nThe duties and responsibilities outlined below include essential functions of the role. Depending on business needs, this role may perform a combination of some or all of the following duties. Duties, responsibilities, and activities may change, or new ones may be assigned.\n\nGather requirements by communicating with researchers, end users, and team members\nManage project priorities, deadlines, and deliverables\nDesign, develop, test, deploy, maintain, and improve software\nCommunicate your software designs and tools through documentation and design reviews\nCollaborate with software engineers, physicists, and product owners to design and develop software solutions\n\n\nRequirements\n\nKnowledge, Skills and Abilities (KSAs)\n\nBachelor’s degree in engineering, computer science or related field and minimum 2 years' work experience; or 5 years' work experience without a Bachelor’s degree\nHigh level of skill and experience with Python\nExperience with at least one compiled systems language, like Rust, C/C++, etc\nSkilled in typical software engineering disciplines: testing, error-handling, readability, documentation, general code health, etc.\nProficient working in a Linux environment\nProficient with data structures and algorithms\nExperience with embedded systems is preferred, but not required\nKnowledge of quantum mechanics is NOT required, but successful applicants should be willing to learn\nDemonstrated ability to effectively share information with technical and non-technical staff\nDemonstrated ability to learn new and complex topics quickly\nDemonstrated ability to work and communicate with all levels of an organization; Professional-level communication skills, including verbal, written, and presentation skills\nDemonstrated ability to work comfortably in a highly collaborative, cross-functional, and team-oriented environment\nDesire and demonstrated ability to thrive and produce results in a fluid, dynamic, and fast-paced environment\nPassion for solving complex problems and challenges in a highly technical and scientific environment\nAbility to travel domestically and (potentially) internationally up to 10%\nThis role requires that you do not require sponsorship or a work visa transfer\n\n\nThis position may require access to information protected under U.S. export control laws and regulations, including the Export Administration Regulations (EAR) and the International Traffic in Arms Regulations (ITAR). Please note that any offer for employment may be conditioned on authorization to receive software or technology controlled under these U.S. export control laws and regulations without sponsorship for an export license\n\nBenefits\n\nIn addition to your base compensation, we offer a generous Total Rewards program which includes:\n\n100% company paid Employee coverage for Medical, Dental, Vision, and Short/Long Term Disability insurance programs\nEmployer funded Health Savings Account\nUnlimited Paid Time Off\n401(k) safe harbor contribution\nCompany paid Life and AD&D Insurance\nFlexible Savings Account\nPaid FMLA Leave\nPaid Maternity/Paternity Leave\nEmploye ...
#   ['Software Developer']],
#  ['3497410864',
#   'Software Engineer',
#   'Rosnet',
# ...
#   ['Marketing Analyst']],
#  ['3496037782',
#   'Marketing Analyst',
#   'TI Fluid Systems',
#   'Description\n\nDescription:\n\nPosition Summary\n\nMarket Analyst capable of developing, maintaining, and presenting accurate sales and market data to all company departments in a concise and timely fashion. Market Analyst will be the key focal point for all sales, market, and competitive information relating to forecasts, tracking vs. forecast, and maintaining historical records.\n\nMarket Analyst capable of developing, maintaining, and presenting accurate sales and market data to all company departments in a concise and timely fashion. Market Analyst will be the key focal point for all sales, market, and competitive information relating to forecasts, tracking vs. forecast, and maintaining historical records.\n\nResponsibilities Of Position\n\nDevelop vehicle production forecast by platform, by month, for use in annual plan. Update on a quarterly basis.\nProvide monthly market review and outlook write-ups to management.\nTrack vehicle production vs. plan and dealer inventory with emphasis on key TI Fluid Systems platforms.\nProvide liaison with Auto-facts and input information into organization as appropriate.\nPrepare sales reports for QOS and operations meetings.\nDevelop and maintain contacts for OEM scheduling information.\nDevelop annual sales plan using $ per vehicle and production forecasts by month by platform.\nMaintain market review charts by platform, track new, replacement, and lost business and the sales impact.\nPrepare market and sales forecast for three year plan submission.\nDevelop and maintain data bases for accurate part % usages, $ per vehicle by product group, and market share vs. competition.\nCoordinate business unit responses to provide consistent format and summaries to information requests.\nProvide analytical and research support and liaison with other TI Fluid Systems’ departments and TI divisions.\nOther duties as assigned.\n\nSkills Requirements\n\nKnowledge of automotive industry and forecasting techniques.\nStrong analytical skills.\nExcellent verbal, written, and presentation skills.\nProficiency in PC skills such as Microsoft Office.\nAbility to interface with all levels of management.\n\nLicensing Or Special Certification Requirements\n\nValid driver’s license.\n\nPhysical Requirements\n\nAbility to travel (including air travel and long automobile trips), including some overnight domestic and international trips.\n\nWorking Conditions\n\nMust work near moving equipment occasionally.\nSome of work time is spent standing, walking, lifting and bending.\nMay be required to travel to plant and/or training sites.\nSome of work time is spent working at a computer.\n\nEducation\n\nEEO Statement:\n\nTI Fluid Systems is committed to\n\nequal employment opportunity regardless of race, color, religion, sex,\n\nnational origin, sexual orientation, age, citizenship, marital status,\n\npregnancy status, disability, gender identity or Veteran status.\nShow more ',
#   ['Marketing Analyst']],
#  ['3485523798',
#   'Marketing Analyst',
#   'Hose Master LLC',
#   "POSITION SUMMARY\n\nThe Marketing Analyst is responsible for conducting marketing analysis to support profitable growth and commercial effectiveness. This involves creating and/or maintaining tools, systems, and processes to collect and analyze data in order to make recommendations on pricing, strategies, and products/services. Additional responsibilities include gathering and reporting competitive intelligence, analyzing customer trends, creating and maintaining customer forecasts in addition to measuring and reporting commercial activity through CRM (Customer Relationship Management) software.\n\n\n\n\nPRIMARY JOB RESPONSIBILITIES\n\nResponsible for tracking, reporting, and analyzing the performance of marketing and sales activities, ad-hoc analytic requests, and development/automation of ongoing reports\nAnalyze sales/margin activity by customer, industry segment, and product lines to identify trends and recommend action\nUnderstand and analyze customer needs, objectives, and requirements to develop and recommend pricing strategies\nDevelop financial models to assess the impact of pricing and other changes on company revenue and profitability\nResearch and collect data on prices, competitors, and market conditions to support pricing decisions\nImplement and record price changes within the appropriate systems as well as communicate as necessary with the appropriate stakeholders\nCreate PowerPoint presentations to provide market and consumer insights to other marketing and sales departments\nProvide data-driven insights to justify action in proposed marketing initiatives\nSupport S&OP initiatives through demand management by creating, maintaining, and communicating monthly forecast by customer and business segment\nCollaborate with cross-function teams to implement marketing (and other) programs that improve the product/service offering\nSupport sales and marketing activity by transforming data into usable information on which to base decisions by creating dashboards in CRM as well as ongoing standard and specialized reporting through PowerPoint and/or Excel\nSupport utilization of the CRM (Customer Relationship Management) software to align organization towards Commercial KPI’s within the Sales and Marketing teams, including a working pipeline and opportunity manager as well as the evaluation of wins and losses\nConduct market research to identify new opportunities for profitable growth in existing markets or new markets for existing products\nLead the analysis and content of information and data to support the quarterly business review process\nAny other reasonable activity as directed by Director of Marketing\n\n\n\n\nQUALIFICATIONS\n\nBachelor's degree in marketing, quantitative discipline, or business related field\n5+ years of sales and/or marketing experience\nStrong analytical skills, critical thinking skills, and problem-solving skills\nAdvanced Excel skills\nWorking knowledge with CRM programs\nProficiency in Microsoft Office Suite\nStrong presentation and communication skills, both verbal and written\nExperience interfacing with national industrial customers (HQ level preferred)\nAbility to effectively implement sales and marketing strategies\nDemonstrated skills in achieving sales, profitability, and budget goals\nHigh-energy self-starter as well as collaborative team player\nProven ability to effectively communicate cross functionally and vertically within company\nDemonstrated commitment to building strong business relationships with customer\n\n\n\n\nCOMPETENCIES\n\nAccountability/Ownership\nAnalytical Ability/Problem Solving/Decision Making\nBusiness Knowledge\nCommunication Skills\nContinuous Learning\nCustomer Service\nInterpersonal/Relationship Skills\nQuality\nSense of Urgency/Entrepreneurialism\nTime Management/Planning/Organizing\nValues/Trust/Integrity\nShow more ",
#   ['Marketing Analyst']],
#  ['3488196177',
#   'Senior Marketing Analyst',
#   'Maxeon Solar Technologies',
#   'Maxeon Solar Technologies is a global leader in solar innovation. Built from 35 years of boundary-pushing solar innovation, Maxeon designs, manufactures, and sells industry-leading SunPower branded solar products. Maxeon is Powering Positive Change every day with a brilliant, passionate and driven team of more than 5,000 people globally.\n\nWe push the boundaries, taking solar technology higher, faster, and farther than before.\n\nWe hold ourselves to a higher standard, striving for the highest integrity, safety, and quality.\n\nWe thrive together as a global team, embracing our diverse backgrounds to make a positive impact on the world.\n\n\n\n\nJoin us in POWERING POSITIVE CHANGE™\n\n\n\n\nJob Summary\n\nReports to Business Analytics and Support Services Team Lead. A regular, full-time position. Responsible for supporting Global Marketing needs of the organization\n\n\n\n\nKey Responsibilities And Accountabilities\n\nProactively develops and keeps up-to-date in-depth knowledge about Digital Marketing and Training\nLeads development and implementation of new programs to support Digital Marketing, and Training initiatives, including marketing campaigns, customer satisfaction, process improvements, and policy design\nDrafts, edits, and manages technical documents to internal and external customers with regards to products, services, transitions, competition, and pricing\nDrafts and edits marketing and other related materials intended for a wide range of stakeholders\nRegularly connects with key stakeholders to identify efficiency opportunities in reporting, upcoming changes with the process and its impact to the team\nInitiates value-adding reporting activities to support Global Marketing team\nPerforms Ad Hoc tasks as assigned\n\n\n\n\nJob Requirements\n\nCandidate must possess at least a bachelor’s degree in Marketing, Information Technology, Business Administration/Management, Engineering, or other related fields\nAt least 1-2 years of experience in marketing automation systems (HubSpot, Eloqua, Marketo etc.)\nAt least 1-2 years of experience in digital and social media marketing.\nAt least one (1) year experience using Salesforce (preferred).\nExperience in using project management tools such as Monday.com, JIRA and Pivotal Tracker.\nStrong knowledge of Microsoft Office with advanced proficiency in Excel\nAbility to process data and formulate plan of action to support data analysis, highly organized and attentive to details\nStrong analytical and problem-solving skills\nCan work with minimum supervision with a strong desire to learn and accept new challenges; results and process-oriented\nProven ability to collaborate effectively across functional business organizations, service-oriented and can effectively manage client requests\nProven negotiating, leadership, and organizational skills\nExcellent oral and written communications skills; able to effectively communicate with people from all levels and multi-cultures\nWilling to work on EU schedule\n\n\n\n\nCritical Competences\n\nMarketing Automation\nMS Office & Maxeon Systems\nCRM\nQuality\nRelationship Management\nDecision-making and Systematic Problem-solving\nProduct/Process Knowledge\nProject Management\nStatistical Analysis\nInnovation\nLeveraging the System\nNegotiation\n\n\n\n\nSafety Compliance\n\nYour safety is our number one priority at Maxeon. All our employees must complete regular workplace safety training and comply with our mandatory safety standards.\n\n\n\n\nEqual Employment Opportunity\n\nIt is Maxeon’s policy to provide equal employment opportunity to all applicants and employees. Maxeon will not tolerate unlawful discrimination against any applicant or employee because of race, color, national origin or ancestry, gender (including pregnancy, childbirth, or related medical conditions), gender identity, age, religion, disability, family care status, veteran status, marital status, sexual orientation, or any other basis protected by national, local, sta ...
#   ['Marketing Analyst']],
#  ['3496620281',
#   'Assistant Manager - Marketing & Insights',
#   'Samsung Gulf',
#   "Job Purpose\n\n\n\n\nThe responsibility of the retail marketing and insights manager is ensuring marketing strategies and promotions for cross-divisional campaigns are consumer centric and are ROI driven. Feed insights to the business to improve performance and always be the voice of the consumer by being the sole source of market data, market outlooks, and budget optimization and always on insights by leveraging partner data and studies conducted. The role also has a key responsibility to execute cross-categories campaigns and activations, therefore marketing experience is a must along with research experience.\n\n\n\n\nResponsibilities\n\n\n\n\nResearch agency stakeholder management (GFK, IDC, Ipsos, Euromonitor etc.)\nRefine market understanding and market outlook to keep the business updated on the market context for better market anticipation\nE-commerce mapping and market sizing update and forecast per category per country in 2023.\nLead on transformational projects in the retail, through traditional retailers and non-traditional\nLead key data & analytics strategic work like MMM, pricing analysis, coverage analysis, etc.\nPresent insight findings to key stakeholders, with actionable recommendations for decision-making. Align stakeholders on data topics.\nDeliver actionable insights via scalable reporting stack & dashboards allowing end-users to identify performance trends, determine root cause, and enable cross-functional actions\nSupport strategic planning processes as well as weekly, monthly and quarterly business reporting along with leading performance reviews with leadership & commercial teams\nDevelop and implement marketing strategies/plan (Advertising / PR Events/Promotions/Exhibitions/ Product Launches) by analyzing current business situations to meet business objectives of the particular category.\nConduct marketing research with the help of external agencies to monitor the competitive landscape of the particular category and keep an eye on performance.\nConduct analysis and periodical reviews of the brand, competition, category, customer and consumer trends to enhance the brand’s equity and marketplace performance.\nResponsibility of managing the overall P&L with action plans for ROI improvement\nOverall responsibility to monitor brand equity of the category and chalk out strategies to strengthen and improve the brand recognition. Developing strategies to exploit market opportunities.\nDevelop and implement marketing strategies/plan viz (Advertising / PR Events/Promotions/Exhibitions/ Product Launches) by analyzing current business situations to meet business objectives of the particular category.\nConduct marketing research with the help of external agencies to monitor the competitive landscape of the particular category and keep an eye on performance.\nConduct analysis and periodical reviews of the brand, competition, category, customer and consumer trends to enhance the brand’s equity and marketplace performance.\nAssist in the execution of cross-divisional campaigns and activations.\nBe the Brand Custodian through all touchpoints\n\n\n\n\nExperience & Qualifications\n\n\n\n\nMinimum 5 to 7 years of experience in Marketing and Insights\nStrong knowledge of research methodologies, strong Excel skills, Presentation skills and Trade excellence acumen.\nSolid experience in marketing execution and innovative marketing campaigns\nExperience in managing overall budget and provide optimization recommendations to the department and management\nBachelor's degree in Marketing or equivalent\nExcellent organizational and planning skills\nStrong verbal and written communication skills\nStrong analytical skills\nAbility to travel within assigned geographic territory\nAbility to strategize and think big picture\nInnovative with strong business acumen\nShow more ",
#   ['Marketing Analyst']]]

# %%
data = pd.DataFrame(data = job_posting_matrix, columns=['Job ID', 'Job Title', 'Company', 'Job Description', 'Job Profile'])

# %%
data['Job ID'] = data['Job ID'].astype(str)
data['Job Profile'] = data['Job Profile'].str[0]

# %%
data.rename(columns = {'Job Description':'Job_Description'}, inplace = True)

# %%
data.to_csv('Job_Posting_dataset.csv', index=False)
